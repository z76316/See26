# %%
from scrapy.crawler import CrawlerProcess
from scrapy.utils.project import get_project_settings

process = CrawlerProcess(get_project_settings())

process.crawl('nba')
process.start()
# Out:
# 2019-06-02 16:14:51 [scrapy.utils.log] INFO: Scrapy 1.6.0 started (bot: crawler)
# 2019-06-02 16:14:51 [scrapy.utils.log] INFO: Versions: lxml 4.3.3.0, libxml2 2.9.9, cssselect 1.0.3, parsel 1.5.1, w3lib 1.20.0, Twisted 19.2.0, Python 3.7.2 (default, Feb 21 2019, 01:27:16) - [Clang 10.0.0 (clang-1000.10.44.4)], pyOpenSSL 19.0.0 (OpenSSL 1.1.1c  28 May 2019), cryptography 2.7, Platform Darwin-18.2.0-x86_64-i386-64bit
# 2019-06-02 16:14:51 [scrapy.crawler] INFO: Overridden settings: {'BOT_NAME': 'crawler', 'FEED_EXPORT_ENCODING': 'utf-8', 'NEWSPIDER_MODULE': 'crawler.spiders', 'ROBOTSTXT_OBEY': True, 'SPIDER_MODULES': ['crawler.spiders']}
# 2019-06-02 16:14:51 [scrapy.extensions.telnet] INFO: Telnet Password: 90a2e8336a2f22cc
# 2019-06-02 16:14:51 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2019-06-02 16:14:51 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2019-06-02 16:14:51 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2019-06-02 16:14:51 [scrapy.middleware] INFO: Enabled item pipelines:
# ['crawler.pipelines.CrawlerPipeline']
# 2019-06-02 16:14:51 [scrapy.core.engine] INFO: Spider opened
# 2019-06-02 16:14:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2019-06-02 16:14:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2019-06-02 16:14:53 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://www.ptt.cc/robots.txt> (referer: None)
# 2019-06-02 16:14:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/bbs/NBA/index.html> (referer: None)
# 2019-06-02 16:14:54 [scrapy.core.scraper] ERROR: Error processing {'author': '-', 'date': ' 6/02', 'href': None, 'push': None, 'title': None}
# Traceback (most recent call last):
#   File "/Users/chia-yuanchang/.pyenv/versions/3.7.2/envs/crawler372/lib/python3.7/site-packages/twisted/internet/defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "/Users/chia-yuanchang/My_Project/See26/crawler/crawler/pipelines.py", line 11, in process_item
#     item['push'] = int(item['push'])
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# 2019-06-02 16:14:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index.html>
# {'author': 'jimmy',
#  'date': ' 6/02',
#  'href': '/bbs/NBA/M.1559462235.A.D80.html',
#  'push': 6,
#  'title': '[討論] 如果暴龍得到總冠軍'}
# 2019-06-02 16:14:54 [scrapy.core.scraper] ERROR: Error processing {'author': 'namie810303',
#  'date': ' 4/07',
#  'href': '/bbs/NBA/M.1554601416.A.281.html',
#  'push': '爆',
#  'title': '[公告] 季後賽期間條款'}
# Traceback (most recent call last):
#   File "/Users/chia-yuanchang/.pyenv/versions/3.7.2/envs/crawler372/lib/python3.7/site-packages/twisted/internet/defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "/Users/chia-yuanchang/My_Project/See26/crawler/crawler/pipelines.py", line 11, in process_item
#     item['push'] = int(item['push'])
# ValueError: invalid literal for int() with base 10: '爆'
# 2019-06-02 16:14:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index.html>
# {'author': 'JerroLi',
#  'date': ' 4/12',
#  'href': '/bbs/NBA/M.1555062827.A.F70.html',
#  'push': 86,
#  'title': '[情報] Playoff Schedule 18–19'}
# 2019-06-02 16:14:54 [scrapy.core.scraper] ERROR: Error processing {'author': 'Vedan',
#  'date': ' 5/24',
#  'href': '/bbs/NBA/M.1558698194.A.1DC.html',
#  'push': None,
#  'title': '[公告] 板規v6.4'}
# Traceback (most recent call last):
#   File "/Users/chia-yuanchang/.pyenv/versions/3.7.2/envs/crawler372/lib/python3.7/site-packages/twisted/internet/defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "/Users/chia-yuanchang/My_Project/See26/crawler/crawler/pipelines.py", line 11, in process_item
#     item['push'] = int(item['push'])
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# 2019-06-02 16:14:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index.html>
# {'author': 'Vedan',
#  'date': ' 5/31',
#  'href': '/bbs/NBA/M.1559274087.A.129.html',
#  'push': 23,
#  'title': '[公告] NBA 板 開始舉辦樂透!'}
# 2019-06-02 16:14:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/bbs/NBA/index6496.html> (referer: https://www.ptt.cc/bbs/NBA/index.html)
# 2019-06-02 16:14:55 [scrapy.core.scraper] ERROR: Error processing {'author': '-', 'date': ' 6/01', 'href': None, 'push': None, 'title': None}
# Traceback (most recent call last):
#   File "/Users/chia-yuanchang/.pyenv/versions/3.7.2/envs/crawler372/lib/python3.7/site-packages/twisted/internet/defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "/Users/chia-yuanchang/My_Project/See26/crawler/crawler/pipelines.py", line 11, in process_item
#     item['push'] = int(item['push'])
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# 2019-06-02 16:14:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6496.html>
# {'author': 'thnlkj0665',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559402278.A.A72.html',
#  'push': 30,
#  'title': '[情報] Ja Morant 將接受膝蓋手術  清除游離體'}
# 2019-06-02 16:14:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6496.html>
# {'author': 'creative',
#  'date': ' 6/02',
#  'href': '/bbs/NBA/M.1559405099.A.65F.html',
#  'push': 78,
#  'title': '[情報] 暴龍側翼搖擺人OG預計G2歸隊'}
# 2019-06-02 16:14:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6496.html>
# {'author': 'shanyaochung',
#  'date': ' 6/02',
#  'href': '/bbs/NBA/M.1559407548.A.94B.html',
#  'push': 29,
#  'title': '[情報] 暴龍 勇士 GAME 2 媒體日影片'}
# 2019-06-02 16:14:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6496.html>
# {'author': 'DarthVader',
#  'date': ' 6/02',
#  'href': '/bbs/NBA/M.1559413027.A.3FC.html',
#  'push': 62,
#  'title': '[花邊] 可愛在場上遇到對手噴垃圾話時的反應'}
# 2019-06-02 16:14:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6496.html>
# {'author': 'munchlax',
#  'date': ' 6/02',
#  'href': '/bbs/NBA/M.1559416163.A.9F2.html',
#  'push': 71,
#  'title': '[花邊] 乳摸幾則'}
# 2019-06-02 16:14:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6496.html>
# {'author': 'sodistrues',
#  'date': ' 6/02',
#  'href': '/bbs/NBA/M.1559442025.A.1CA.html',
#  'push': 18,
#  'title': '[花邊]暴龍替補後衛找回準星 他爆粗口挺林書豪'}
# 2019-06-02 16:14:55 [scrapy.core.scraper] ERROR: Error processing {'author': 'liuuuuuu',
#  'date': ' 6/02',
#  'href': '/bbs/NBA/M.1559442520.A.A12.html',
#  'push': '爆',
#  'title': '[新聞] 利物浦歐冠聯賽奪金盃 詹姆斯股份暴漲7倍'}
# Traceback (most recent call last):
#   File "/Users/chia-yuanchang/.pyenv/versions/3.7.2/envs/crawler372/lib/python3.7/site-packages/twisted/internet/defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "/Users/chia-yuanchang/My_Project/See26/crawler/crawler/pipelines.py", line 11, in process_item
#     item['push'] = int(item['push'])
# ValueError: invalid literal for int() with base 10: '爆'
# 2019-06-02 16:14:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6496.html>
# {'author': 'bbbyes123',
#  'date': ' 6/02',
#  'href': '/bbs/NBA/M.1559444372.A.78E.html',
#  'push': 59,
#  'title': '[新聞] 主導比賽實現童年夢想 雷納德:每場能投20'}
# 2019-06-02 16:14:55 [scrapy.core.scraper] ERROR: Error processing {'author': '-', 'date': ' 6/02', 'href': None, 'push': None, 'title': None}
# Traceback (most recent call last):
#   File "/Users/chia-yuanchang/.pyenv/versions/3.7.2/envs/crawler372/lib/python3.7/site-packages/twisted/internet/defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "/Users/chia-yuanchang/My_Project/See26/crawler/crawler/pipelines.py", line 11, in process_item
#     item['push'] = int(item['push'])
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# 2019-06-02 16:14:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6496.html>
# {'author': 'smalltalker',
#  'date': ' 6/02',
#  'href': '/bbs/NBA/M.1559446470.A.D22.html',
#  'push': 63,
#  'title': '[專欄]打遍多倫多無敵手 Curry與北境的短暫緣份'}
# 2019-06-02 16:14:55 [scrapy.core.scraper] ERROR: Error processing {'author': '-', 'date': ' 6/02', 'href': None, 'push': 'X1', 'title': None}
# Traceback (most recent call last):
#   File "/Users/chia-yuanchang/.pyenv/versions/3.7.2/envs/crawler372/lib/python3.7/site-packages/twisted/internet/defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "/Users/chia-yuanchang/My_Project/See26/crawler/crawler/pipelines.py", line 11, in process_item
#     item['push'] = int(item['push'])
# ValueError: invalid literal for int() with base 10: 'X1'
# 2019-06-02 16:14:55 [scrapy.core.scraper] ERROR: Error processing {'author': '-', 'date': ' 6/02', 'href': None, 'push': None, 'title': None}
# Traceback (most recent call last):
#   File "/Users/chia-yuanchang/.pyenv/versions/3.7.2/envs/crawler372/lib/python3.7/site-packages/twisted/internet/defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "/Users/chia-yuanchang/My_Project/See26/crawler/crawler/pipelines.py", line 11, in process_item
#     item['push'] = int(item['push'])
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# 2019-06-02 16:14:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6496.html>
# {'author': 'bigDwinsch',
#  'date': ' 6/02',
#  'href': '/bbs/NBA/M.1559454156.A.870.html',
#  'push': 20,
#  'title': '[花邊] logo爺將獲得美國公民最高榮譽，總統自由勳章'}
# 2019-06-02 16:14:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6496.html>
# {'author': 'MrSatan',
#  'date': ' 6/02',
#  'href': '/bbs/NBA/M.1559454230.A.52B.html',
#  'push': 17,
#  'title': '[情報] 歷屆冠軍隊,入選過明星賽的球員'}
# 2019-06-02 16:14:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6496.html>
# {'author': 'WIGGINS22',
#  'date': ' 6/02',
#  'href': '/bbs/NBA/M.1559454700.A.16A.html',
#  'push': 16,
#  'title': '[新聞] T-Mac調侃從未見過Lowry左手傳球，Lowry'}
# 2019-06-02 16:14:55 [scrapy.core.scraper] ERROR: Error processing {'author': 'FieldGoal',
#  'date': ' 6/02',
#  'href': '/bbs/NBA/M.1559455127.A.7C2.html',
#  'push': None,
#  'title': '[討論] 暴龍第二場要怎麼樣才能贏勇士？'}
# Traceback (most recent call last):
#   File "/Users/chia-yuanchang/.pyenv/versions/3.7.2/envs/crawler372/lib/python3.7/site-packages/twisted/internet/defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "/Users/chia-yuanchang/My_Project/See26/crawler/crawler/pipelines.py", line 11, in process_item
#     item['push'] = int(item['push'])
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# 2019-06-02 16:14:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6496.html>
# {'author': 'DAHSU',
#  'date': ' 6/02',
#  'href': '/bbs/NBA/M.1559455312.A.414.html',
#  'push': 3,
#  'title': 'Re: [花邊]暴龍替補後衛找回準星 他爆粗口挺林書豪'}
# 2019-06-02 16:14:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6496.html>
# {'author': 'gt097231',
#  'date': ' 6/02',
#  'href': '/bbs/NBA/M.1559455694.A.F30.html',
#  'push': 41,
#  'title': '[花邊] 勇士首戰踢到鐵板 格林：湯普森被激怒了'}
# 2019-06-02 16:14:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6496.html>
# {'author': 'bigDwinsch',
#  'date': ' 6/02',
#  'href': '/bbs/NBA/M.1559456549.A.979.html',
#  'push': 44,
#  'title': '[情報] Leonard：相較於之前打總冠，我今年開始享受這份樂趣'}
# 2019-06-02 16:14:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/bbs/NBA/index6495.html> (referer: https://www.ptt.cc/bbs/NBA/index6496.html)
# 2019-06-02 16:14:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6495.html>
# {'author': 'gt097231',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559361505.A.1CC.html',
#  'push': 73,
#  'title': '[情報] Rubio：Marc Gasol能征戰總決賽讓我嫉妒'}
# 2019-06-02 16:14:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6495.html>
# {'author': 'lovea',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559361889.A.0E1.html',
#  'push': 71,
#  'title': '[花邊] 2天前急尋老柯瑞暴龍球衣 德瑞克成功引爆'}
# 2019-06-02 16:14:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6495.html>
# {'author': 'abrring',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559362983.A.BDF.html',
#  'push': 59,
#  'title': '[新聞] 雷納德超搶手\u3000但傳言他將留在暴龍'}
# 2019-06-02 16:14:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6495.html>
# {'author': 'manuginobii',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559363632.A.7B6.html',
#  'push': 32,
#  'title': '[情報] 嘴綠談Drake:不介意他的行為 這非常有趣'}
# 2019-06-02 16:14:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6495.html>
# {'author': 'fack3170',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559363806.A.CB9.html',
#  'push': 86,
#  'title': '[花邊] 共進晚餐！Jeanie Buss曬出與Kuzma合影:'}
# 2019-06-02 16:14:56 [scrapy.core.scraper] ERROR: Error processing {'author': 'thnlkj0665',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559365233.A.C6A.html',
#  'push': '爆',
#  'title': '[花邊] 少詹皇差很大? 全美總冠軍賽收視率十年新低'}
# Traceback (most recent call last):
#   File "/Users/chia-yuanchang/.pyenv/versions/3.7.2/envs/crawler372/lib/python3.7/site-packages/twisted/internet/defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "/Users/chia-yuanchang/My_Project/See26/crawler/crawler/pipelines.py", line 11, in process_item
#     item['push'] = int(item['push'])
# ValueError: invalid literal for int() with base 10: '爆'
# 2019-06-02 16:14:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6495.html>
# {'author': 'seacore07',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559374114.A.05B.html',
#  'push': 31,
#  'title': '[新聞] 總冠軍賽三分球累積破百 柯瑞史上第一人'}
# 2019-06-02 16:14:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6495.html>
# {'author': 'HOlajuwon',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559375533.A.579.html',
#  'push': 49,
#  'title': 'Re: [花邊] 少詹皇差很大? 全美總冠軍賽收視率十年新低'}
# 2019-06-02 16:14:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6495.html>
# {'author': 'sk050607',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559377265.A.0DC.html',
#  'push': 3,
#  'title': 'Re: [花邊] 少詹皇差很大? 全美總冠軍賽收視率十年新低'}
# 2019-06-02 16:14:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6495.html>
# {'author': 'Yui5',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559378757.A.356.html',
#  'push': 50,
#  'title': '[花邊] Kerr：加拿大的球迷真的很棒，說垃圾話都'}
# 2019-06-02 16:14:56 [scrapy.core.scraper] ERROR: Error processing {'author': 'AndyRautins',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559378954.A.98E.html',
#  'push': '爆',
#  'title': '[情報] 字母哥：從KL身上學到很多 中距離很重要'}
# Traceback (most recent call last):
#   File "/Users/chia-yuanchang/.pyenv/versions/3.7.2/envs/crawler372/lib/python3.7/site-packages/twisted/internet/defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "/Users/chia-yuanchang/My_Project/See26/crawler/crawler/pipelines.py", line 11, in process_item
#     item['push'] = int(item['push'])
# ValueError: invalid literal for int() with base 10: '爆'
# 2019-06-02 16:14:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6495.html>
# {'author': 'DD0730',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559381041.A.206.html',
#  'push': 15,
#  'title': 'Re: [花邊] 少詹皇差很大? 全美總冠軍賽收視率十年新低'}
# 2019-06-02 16:14:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6495.html>
# {'author': 'Yui5',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559381159.A.8F2.html',
#  'push': 84,
#  'title': '[情報] 某GM談CP3：他沒了速度還背了一份大合約'}
# 2019-06-02 16:14:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6495.html>
# {'author': 'luganzhin',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559382082.A.474.html',
#  'push': 28,
#  'title': '[花邊] Juwan Howard預計接密西根帥位'}
# 2019-06-02 16:14:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6495.html>
# {'author': 'bigDwinsch',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559383491.A.984.html',
#  'push': 17,
#  'title': '[花邊] T.Young嘗試足球橫梁挑戰：對於初學者來說也還不錯'}
# 2019-06-02 16:14:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6495.html>
# {'author': 'fack3170',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559386770.A.D56.html',
#  'push': 41,
#  'title': '[新聞] 澳籃隊伍抓內鬼 安東尼意外成主角'}
# 2019-06-02 16:14:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6495.html>
# {'author': 'bigDwinsch',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559387520.A.3C7.html',
#  'push': 52,
#  'title': '[情報] Iguodala連續10記三分不中，上次投進是與火箭的G6'}
# 2019-06-02 16:14:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.ptt.cc/bbs/NBA/index6495.html>
# {'author': 'MrSatan',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559387882.A.366.html',
#  'push': 25,
#  'title': '[情報] 球員3分場均命中最高5年的3P% (3PM/G>=2)'}
# 2019-06-02 16:14:56 [scrapy.core.scraper] ERROR: Error processing {'author': 'walter1994',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559397314.A.370.html',
#  'push': '爆',
#  'title': '[討論] Kobe還有哪些招是KL不會的??'}
# Traceback (most recent call last):
#   File "/Users/chia-yuanchang/.pyenv/versions/3.7.2/envs/crawler372/lib/python3.7/site-packages/twisted/internet/defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "/Users/chia-yuanchang/My_Project/See26/crawler/crawler/pipelines.py", line 11, in process_item
#     item['push'] = int(item['push'])
# ValueError: invalid literal for int() with base 10: '爆'
# 2019-06-02 16:14:56 [scrapy.core.scraper] ERROR: Error processing {'author': 'Gotham',
#  'date': ' 6/01',
#  'href': '/bbs/NBA/M.1559398450.A.B57.html',
#  'push': '爆',
#  'title': '[新聞] 總冠軍賽第2戰 Durant仍無法出賽'}
# Traceback (most recent call last):
#   File "/Users/chia-yuanchang/.pyenv/versions/3.7.2/envs/crawler372/lib/python3.7/site-packages/twisted/internet/defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "/Users/chia-yuanchang/My_Project/See26/crawler/crawler/pipelines.py", line 11, in process_item
#     item['push'] = int(item['push'])
# ValueError: invalid literal for int() with base 10: '爆'
# 2019-06-02 16:14:56 [scrapy.core.engine] INFO: Closing spider (Close it)
# 2019-06-02 16:14:56 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1194,
#  'downloader/request_count': 4,
#  'downloader/request_method_count/GET': 4,
#  'downloader/response_bytes': 11931,
#  'downloader/response_count': 4,
#  'downloader/response_status_count/200': 3,
#  'downloader/response_status_count/404': 1,
#  'finish_reason': 'Close it',
#  'finish_time': datetime.datetime(2019, 6, 2, 8, 14, 56, 139853),
#  'item_scraped_count': 33,
#  'log_count/DEBUG': 37,
#  'log_count/ERROR': 13,
#  'log_count/INFO': 9,
#  'memusage/max': 81567744,
#  'memusage/startup': 81567744,
#  'request_depth_max': 2,
#  'response_received_count': 4,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/404': 1,
#  'scheduler/dequeued': 3,
#  'scheduler/dequeued/memory': 3,
#  'scheduler/enqueued': 3,
#  'scheduler/enqueued/memory': 3,
#  'start_time': datetime.datetime(2019, 6, 2, 8, 14, 52, 814)}
# 2019-06-02 16:14:56 [scrapy.core.engine] INFO: Spider closed (Close it)
